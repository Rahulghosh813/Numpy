# %%
def eqspace(a,b,c):
  list1=[]
  list1.append(float(a))
  c=c-1
  x=(float(b)-float(a))/float(c)
  for i in range(1,c):
    a=a+x;
    list1.append(a)
  list1.append(float(b))
  import array
  arr=array.array('f',list1)
  print(arr)
  return

# %%
eqspace(10,30,5)
# Out:
# array('f', [10.0, 15.0, 20.0, 25.0, 30.0])
